# %% [markdown]
# #📌 Extracão

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a28f480b-2ec1-40e1-bb4a-e060fcad5e59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a28f480b-2ec1-40e1-bb4a-e060fcad5e59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
teleconX = pd.read_json('/content/TelecomX_Data.json')
teleconX
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
teleconX_customer = pd.json_normalize(teleconX['customer'])
teleconX_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
teleconX_phone = pd.json_normalize(teleconX['phone'])
teleconX_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
teleconX_internet = pd.json_normalize(teleconX['internet'])
teleconX_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
teleconX_account = pd.json_normalize(teleconX['account'])
teleconX_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
dados = pd.concat([teleconX, teleconX_customer, teleconX_phone, teleconX_internet, teleconX_account], axis=1)
dados = dados.drop(columns=['customer', 'phone', 'internet', 'account'])
dados.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %% [markdown]
# #🔧 Transformação

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
import  numpy as np
dados['Charges.Total'] = dados['Charges.Total'].replace(' ', np.nan, regex=True)
dados['Charges.Total'] = dados['Charges.Total'].replace('', np.nan, regex=True)
dados['Charges.Total'] = dados['Charges.Total'].astype(np.float64)
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
dados['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
dados['Churn'] = dados['Churn'].replace('', np.nan, regex=True)

# %%
dados.dropna(subset=['Charges.Total'], inplace=True)
dados.dropna(subset=['Churn'], inplace=True)
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   Churn             7032 non-null   object
#  2   gender            7032 non-null   object
#  3   SeniorCitizen     7032 non-null   int64
#  4   Partner           7032 non-null   object
#  5   Dependents        7032 non-null   object
#  6   tenure            7032 non-null   int64
#  7   PhoneService      7032 non-null   object
#  8   MultipleLines     7032 non-null   object
#  9   InternetService   7032 non-null   object
#  10  OnlineSecurity    7032 non-null   object
#  11  OnlineBackup      7032 non-null   object
#  12  DeviceProtection  7032 non-null   object
#  13  TechSupport       7032 non-null   object
#  14  StreamingTV       7032 non-null   object
#  15  StreamingMovies   7032 non-null   object
# ...

# %%
dias_no_mes = 30
dados['Contas_Diarias'] = dados['Charges.Monthly'] / dias_no_mes
print("DataFrame com a nova coluna 'Contas_Diarias':")
print(dados[['Charges.Monthly', 'Contas_Diarias']].head())
# Out:
# DataFrame com a nova coluna 'Contas_Diarias':
#    Charges.Monthly  Contas_Diarias
# 0             65.6        2.186667
# 1             59.9        1.996667
# 2             73.9        2.463333
# 3             98.0        3.266667
# 4             83.9        2.796667

# %%
dicionario_traducao = {
    'customerID': 'ID',
    'gender': 'Genero',
    'SeniorCitizen': 'Cidadao_Senior',
    'Partner': 'Parceiro',
    'Dependents': 'Dependentes',
    'tenure': 'Tempo_De_Servico_Meses',
    'PhoneService': 'Servico_Telefone',
    'MultipleLines': 'Multiplas_Linhas',
    'InternetService': 'Servico_Internet',
    'OnlineSecurity': 'Seguranca_Online',
    'OnlineBackup': 'Backup_Online',
    'DeviceProtection': 'Protecao_Dispositivo',
    'TechSupport': 'Suporte_Tecnico',
    'StreamingTV': 'Streaming_TV',
    'StreamingMovies': 'Streaming_Filmes',
    'Contract': 'Tipo_De_Contrato',
    'PaperlessBilling': 'Faturamento_Sem_Papel',
    'PaymentMethod': 'Metodo_De_Pagamento',
    'Charges.Monthly': 'Cobranca_Mensal',
    'Charges.Total': 'Cobranca_Total',
    'Churn': 'Evasao'
}
dados.rename(columns=dicionario_traducao, inplace=True)
print("Colunas do DataFrame após a tradução:")
print(dados.columns)
# Out:
# Colunas do DataFrame após a tradução:
# Index(['ID', 'Evasao', 'Genero', 'Cidadao_Senior', 'Parceiro', 'Dependentes',
#        'Tempo_De_Servico_Meses', 'Servico_Telefone', 'Multiplas_Linhas',
#        'Servico_Internet', 'Seguranca_Online', 'Backup_Online',
#        'Protecao_Dispositivo', 'Suporte_Tecnico', 'Streaming_TV',
#        'Streaming_Filmes', 'Tipo_De_Contrato', 'Faturamento_Sem_Papel',
#        'Metodo_De_Pagamento', 'Cobranca_Mensal', 'Cobranca_Total',
#        'Contas_Diarias'],
#       dtype='object')

# %%
df_evasao = dados[dados['Evasao'] == 'Yes']
print("DataFrame com apenas os clientes que saíram (Evasao = 'Yes'):")
df_evasao.head()
# Out:
# DataFrame com apenas os clientes que saíram (Evasao = 'Yes'):
#             ID Evasao  Genero  Cidadao_Senior Parceiro Dependentes  \
# 2   0004-TLHLJ    Yes    Male               0       No          No
# 3   0011-IGKFF    Yes    Male               1      Yes          No
# 4   0013-EXCHZ    Yes  Female               1      Yes          No
# 18  0022-TCJCI    Yes    Male               1       No          No
# 19  0023-HGHWL    Yes    Male               1       No          No
#
#     Tempo_De_Servico_Meses Servico_Telefone  Multiplas_Linhas  \
# 2                        4              Yes                No
# 3                       13              Yes                No
# 4                        3              Yes                No
# 18                      45              Yes                No
# 19                       1               No  No phone service
#
#    Servico_Internet  ... Protecao_Dispositivo Suporte_Tecnico Streaming_TV  \
# ...

# %%
df_evasao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1869 entries, 2 to 7263
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      1869 non-null   object
#  1   Evasao                  1869 non-null   object
#  2   Genero                  1869 non-null   object
#  3   Cidadao_Senior          1869 non-null   int64
#  4   Parceiro                1869 non-null   object
#  5   Dependentes             1869 non-null   object
#  6   Tempo_De_Servico_Meses  1869 non-null   int64
#  7   Servico_Telefone        1869 non-null   object
#  8   Multiplas_Linhas        1869 non-null   object
#  9   Servico_Internet        1869 non-null   object
#  10  Seguranca_Online        1869 non-null   object
#  11  Backup_Online           1869 non-null   object
#  12  Protecao_Dispositivo    1869 non-null   object
#  13  Suporte_Tecnico         1869 non-null   object
# ...

# %% [markdown]
# #📊 Carga e análise

# %% [markdown]
# Análise Descritiva

# %%
# Df Completo
dados.describe()
# Out:
#        Cidadao_Senior  Tempo_De_Servico_Meses  Cobranca_Mensal  \
# count     7032.000000             7032.000000      7032.000000
# mean         0.162400               32.421786        64.798208
# std          0.368844               24.545260        30.085974
# min          0.000000                1.000000        18.250000
# 25%          0.000000                9.000000        35.587500
# 50%          0.000000               29.000000        70.350000
# 75%          0.000000               55.000000        89.862500
# max          1.000000               72.000000       118.750000
#
#        Cobranca_Total  Contas_Diarias
# count     7032.000000     7032.000000
# mean      2283.300441        2.159940
# std       2266.771362        1.002866
# min         18.800000        0.608333
# 25%        401.450000        1.186250
# 50%       1397.475000        2.345000
# 75%       3794.737500        2.995417
# max       8684.800000        3.958333

# %%
# Df de evasão
df_evasao.describe()
# Out:
#        Cidadao_Senior  Tempo_De_Servico_Meses  Cobranca_Mensal  \
# count     1869.000000             1869.000000      1869.000000
# mean         0.254682               17.979133        74.441332
# std          0.435799               19.531123        24.666053
# min          0.000000                1.000000        18.850000
# 25%          0.000000                2.000000        56.150000
# 50%          0.000000               10.000000        79.650000
# 75%          1.000000               29.000000        94.200000
# max          1.000000               72.000000       118.350000
#
#        Cobranca_Total  Contas_Diarias
# count     1869.000000     1869.000000
# mean      1531.796094        2.481378
# std       1890.822994        0.822202
# min         18.850000        0.628333
# 25%        134.500000        1.871667
# 50%        703.550000        2.655000
# 75%       2331.300000        3.140000
# max       8684.800000        3.945000

# %% [markdown]
# Distribuição da Evasão

# %%
import matplotlib.pyplot as plt
import seaborn as sns
distribuicao_evasao = dados['Evasao'].value_counts()
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=distribuicao_evasao.index, y=distribuicao_evasao.values)
plt.title('Distribuição da Evasão de Clientes', fontsize=16)
plt.xlabel('Evasão do Cliente', fontsize=12)
plt.ylabel('Número de Clientes', fontsize=12)
plt.show()

# %% [markdown]
# Contagem de Evasão por Variáveis Categóricas

# %%
# %matplotlib inline

# %%
cor_evasao = ['#c44e52']
fig, (ax1, ax2, ax3,) = plt.subplots(1, 3, figsize=(23, 6))


# dados para cada gráfico
genero = df_evasao['Genero'].value_counts()
tipo_contrato = df_evasao['Tipo_De_Contrato'].value_counts()
pagamento = df_evasao['Metodo_De_Pagamento'].value_counts()


# Genero

genero.plot(kind='bar', stacked=False, ax=ax1, rot=0, color=cor_evasao)
ax1.set_title('Evasão por Gênero', fontsize=14)
ax1.set_xlabel('')
ax1.set_ylabel('Número de Clientes', fontsize=10)
ax1.legend('')

# Tipo_De_Contrato
tipo_contrato.plot(kind='bar', stacked=False, ax=ax2, rot=0, color=cor_evasao)
ax2.set_title('Evasão por Tipo de Contrato', fontsize=14)
ax2.set_xlabel('')
ax2.set_ylabel('')


# método de pagamento
pagamento.plot(kind='bar', stacked=False, ax=ax3, rot=0, color=cor_evasao)
ax3.set_title('Evasão por Método de Pagamento')
ax3.set_xlabel('')
ax3.set_ylabel('')


ymin = 0
ymax = 1700
# Correção: Itere sobre a lista [ax1, ax2] que contém seus gráficos
for ax in [ax1, ax2, ax3]:
    ax.set_ylim(ymin, ymax)
    ax.tick_params(axis='x', rotation=45)

# %% [markdown]
# Evasão por Variáveis Numéricas

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Evasao', y='Cobranca_Total', data=dados, palette=['#5cb85c', '#c44e52'])
plt.title('Distribuição de Cobrança Total por Status de Evasão', fontsize=16)
plt.xlabel('')
plt.ylabel('Cobranca Total', fontsize=12)
plt.xticks([0, 1], ['Não Evadiu', 'Evadiu']) # Define rótulos mais descritivos
plt.show()
# Out:
# /tmp/ipython-input-3906910809.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Evasao', y='Cobranca_Total', data=dados, palette=['#5cb85c', '#c44e52'])

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Evasao', y='Tempo_De_Servico_Meses', data=dados, palette=['#5cb85c', '#c44e52'])
plt.title('Distribuição de Cobrança Total por Status de Evasão', fontsize=16)
plt.xlabel('')
plt.ylabel('Tempo De Servico', fontsize=12)
plt.xticks([0, 1], ['Não Evadiu', 'Evadiu']) # Define rótulos mais descritivos
plt.show()
# Out:
# /tmp/ipython-input-3794857066.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Evasao', y='Tempo_De_Servico_Meses', data=dados, palette=['#5cb85c', '#c44e52'])

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# # Relatório Final - Análise de Evasão de Clientes (Churn) da TelecomX
#
# ## 1. Introdução
#
# ### Objetivo da Análise
# O presente estudo tem como objetivo principal analisar o conjunto de dados da empresa de telecomunicações TelecomX para identificar os fatores que mais contribuem para a evasão de clientes, fenômeno conhecido como *Churn*.
#
# ### O Problema do Churn
# A evasão de clientes é uma métrica crítica para empresas com modelo de assinatura, como as de telecomunicações. Reter um cliente existente é significativamente mais econômico do que adquirir um novo. Portanto, entender as causas do churn permite à empresa desenvolver estratégias de retenção mais eficazes, melhorar a satisfação do cliente e, consequentemente, aumentar sua lucratividade e estabilidade no mercado. Esta análise busca desvendar os perfis de clientes com maior propensão a cancelar seus serviços, fornecendo insights valiosos para a tomada de decisão.
#
# ## 2. Limpeza e Tratamento de Dados
#
# Para garantir a qualidade e a precisão da análise, os dados brutos passaram por um rigoroso processo de extração, limpeza e transformação. As principais etapas foram:
#
# -   **Importação e Extração:** Os dados foram importados de um arquivo no formato JSON (`TelecomX_Data.json`). A estrutura inicial continha colunas aninhadas (`customer`, `phone`, `internet`, `account`), que armazenavam múltiplas informações.
# -   **Normalização dos Dados:** As colunas aninhadas foram "achatadas" (normalizadas) utilizando a função `pd.json_normalize`. Cada coluna aninhada foi transformada em um DataFrame separado, expondo suas informações em colunas individuais.
# -   **Consolidação:** Os DataFrames normalizados foram concatenados ao DataFrame principal, criando uma única tabela com todas as variáveis disponíveis para análise. As colunas aninhadas originais foram removidas.
# -   **Tratamento de Tipos e Dados Faltantes:**
#     -   A coluna `Charges.Total` (Cobrança Total) estava como tipo `object` (texto) devido a valores em branco. Esses valores foram identificados, convertidos para `NaN` (nulos) e as linhas correspondentes foram removidas para evitar distorções nos cálculos. Em seguida, a coluna foi convertida para o tipo numérico `float64`.
#     -   A coluna `Churn` (Evasão) também continha valores em branco, que foram tratados como nulos e, posteriormente, as linhas foram removidas.
# -   **Criação de Novas Variáveis (Feature Engineering):** Foi criada a coluna `Contas_Diarias`, calculada a partir da divisão da `Charges.Monthly` por 30, para permitir uma análise de custo sob uma perspectiva diária.
# -   **Tradução e Renomeação:** Para facilitar a compreensão, todas as colunas foram renomeadas para o português.
#
# ## 3. Análise Exploratória de Dados
#
# Após o tratamento, foi realizada uma análise exploratória para identificar padrões e correlações entre as variáveis e a evasão de clientes.
#
# ### 3.1. Distribuição Geral da Evasão
# A primeira análise mostrou a proporção de clientes que evadiram em comparação com os que permaneceram. Dos mais de 7.000 clientes na base tratada, 1.869 cancelaram o serviço.
#
# ### 3.2. Fatores Demográficos e Contratuais da Evasão
# Analisando apenas o grupo de clientes que evadiu (`df_evasao`), observamos alguns padrões claros:
#
# -   **Gênero:** A evasão é praticamente idêntica entre os gêneros masculino e feminino, sugerindo que o gênero não é um fator determinante para o cancelamento do serviço.
# -   **Tipo de Contrato:** Este é um dos indicadores mais fortes. A grande maioria dos clientes que cancelaram possuía um contrato **Mês a Mês**. Clientes com contratos de um ou dois anos demonstram uma taxa de evasão drasticamente menor, indicando maior lealdade.
# -   **Método de Pagamento:** O pagamento via **Cheque Eletrônico** é o método predominante entre os clientes que saíram da empresa, superando com folga outros métodos como cartão de crédito e débito em conta.
#
# ### 3.3. Fatores Numéricos da Evasão
# A análise de variáveis numéricas também revelou diferenças importantes entre os clientes que ficaram e os que saíram:
#
# -   **Tempo de Serviço (Meses):** O boxplot mostra que clientes que evadiram têm, em média, um tempo de serviço muito menor. A mediana de permanência desse grupo é de apenas 10 meses, enquanto a dos clientes que ficaram é de 38 meses. Isso indica que a evasão é mais comum no início do ciclo de vida do cliente.
# -   **Cobrança Total:** Como esperado, a cobrança total acumulada dos clientes que evadiram é significativamente menor, o que é uma consequência direta do menor tempo de serviço com a empresa.
#
# ## 4. Conclusões e Insights
#
# A análise dos dados permitiu traçar um perfil claro do cliente com maior risco de evasão:
#
# -   **Principal Indicador de Risco:** O **Tipo de Contrato** é o fator mais preditivo. Clientes no plano "Mês a Mês" são muito mais propensos a cancelar.
# -   **Perfil de Risco:** Um cliente com **pouco tempo de casa** (`baixa Tempo_De_Servico_Meses`) e que utiliza **Cheque Eletrônico** como forma de pagamento também apresenta um risco elevado de churn.
# -   **Cobrança Mensal:** Embora a cobrança total seja menor para quem evade, a análise descritiva (`df_evasao.describe()`) mostrou que a **cobrança mensal média** para esse grupo (74.44) é maior que a média geral dos clientes (64.80). Isso pode sugerir que clientes com planos mais caros (como fibra óptica, que geralmente tem um custo maior) e sem um contrato de longo prazo são mais sensíveis a preço e concorrência.
#
# ## 5. Recomendações
#
# Com base nos insights gerados, as seguintes ações são recomendadas para a TelecomX com o objetivo de reduzir a taxa de churn:
#
# 1.  **Incentivar Contratos de Longo Prazo:** Criar campanhas de marketing e ofertas agressivas para incentivar os clientes do plano "Mês a Mês" a migrarem para contratos de 1 ou 2 anos. Benefícios podem incluir descontos na mensalidade, upgrade de serviço ou bônus exclusivos.
# 2.  **Ações de Retenção para Novos Clientes:** Focar os esforços de retenção nos primeiros meses de vida do cliente, que é o período mais crítico. Oferecer um acompanhamento proativo, pesquisas de satisfação e ofertas especiais de fidelização após o 3º ou 6º mês pode fortalecer o relacionamento.
# 3.  **Analisar o Método de Pagamento "Cheque Eletrônico":** Investigar por que este método está tão associado à evasão. Pode haver atritos no processo de pagamento ou pode ser o método preferido por clientes com menor intenção de permanência. Oferecer pequenos descontos para a migração para métodos de pagamento automáticos (cartão de crédito ou débito em conta) pode ser uma estratégia eficaz.
# 4.  **Revisar a Oferta de Valor para Planos Mais Caros:** Dado que a cobrança mensal média dos clientes que evadem é maior, é importante garantir que o valor percebido desses planos (ex: fibra óptica) justifique o custo, especialmente para quem não tem um vínculo de longo prazo. Ações como pacotes de serviços agregados podem aumentar a percepção de valor.
